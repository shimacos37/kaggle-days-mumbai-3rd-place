# %%
import os
import gc
import joblib
import random
import numpy as np
import pandas as pd
from pathlib import Path
from tqdm.auto import tqdm
from argparse import Namespace
from collections import defaultdict
from scipy.signal import find_peaks

import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import pearsonr
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.model_selection import TimeSeriesSplit, StratifiedKFold, GroupKFold, train_test_split, KFold

import lightgbm as lgb

import warnings
warnings.filterwarnings('ignore')
pd.set_option('max_columns', 64)

from sklearn import model_selection, metrics

# %%
df = pd.read_csv('../input/we-are-all-alike-on-the-inside/train.csv')
test_org = pd.read_csv('../input/we-are-all-alike-on-the-inside/test.csv')
df['target'] = df['category'].map(
{
    'association':0,
    'disagreement':1,
    'unbiased':2,
})

# %%
# sakami_data
sakami_folder_list = ['v1', 'v2', 'v3', 'v5']
oof_dict = {}
test_dict = {}

for sakami_folder in sakami_folder_list:
    oof = pd.read_csv(f'../input/gcsdata/sakami/{sakami_folder}/valid.csv')
    test = pd.read_csv(f'../input/gcsdata/sakami/{sakami_folder}/test.csv').sort_values('id')
    oof = oof.merge(df[['id', 'category', 'target']]).sort_values('id')
    pred_cols = ['association','disagreement', 'unbiased']
    oof = oof.loc[oof[pred_cols].sum(axis=1) != 0]
    test['target'] = test[pred_cols].to_numpy().argmax(axis=1)
    test[pred_cols] *= 4
    test['category'] = test['target'].map({
        0: 'association',
        1: 'disagreement',
        2: 'unbiased',
    })
    
    for c in pred_cols:
        oof[f'f_{c}_{sakami_folder}'] = oof[c]
        test[f'f_{c}_{sakami_folder}'] = test[c]
    oof_dict[f'sakami{sakami_folder}'] = oof
    test_dict[f'sakami{sakami_folder}'] = test
    
    # test[['id', 'category']].to_csv(f'../output/sub_{sakami_folder}_sakami.csv', index=False)
    print(metrics.f1_score(oof['target'], oof[pred_cols].to_numpy().argmax(axis=1), average='micro'))
# Out:
# 0.7942130778333397
# 0.7918082223155323
# 0.7848417757758522
# 0.7891170744741764

# %%
# shimacos データ
oof = pd.read_csv('../input/gcsdata/shima/v0/valid_fold0.csv').rename(
    columns={
        'category_pred_0': 'association',
        'category_pred_1': 'disagreement',
        'category_pred_2': 'unbiased',
    }
).drop_duplicates('id').sort_values('id')
del oof['category_pred'], oof['category']
oof = oof.merge(df[['id', 'category', 'target']])
for c in pred_cols:
    oof[f'f_{c}_shima'] = oof[c]

test = pd.read_csv('../input/gcsdata/shima/v0/test_fold0.csv').rename(
    columns={
        'category_pred_0': 'association',
        'category_pred_1': 'disagreement',
        'category_pred_2': 'unbiased',
    }
).drop_duplicates('id').sort_values('id')
# del test['category_pred'], test['category']
# test = test.merge(df[['id', 'category', 'target']])
for c in pred_cols:
    test[f'f_{c}_shima'] = test[c]
    

oof_dict['shima_v0'] = oof
test_dict['shima_v0'] = test
print(metrics.f1_score(oof['target'], oof[pred_cols].to_numpy().argmax(axis=1), average='micro'))


# ensemble スコア
p = np.zeros([len(oof), 3])

for key, w in zip(['sakamiv1', 'sakamiv2', 'sakamiv3', 'shima_v0'], [0.2, 0.1, 0.1, 0.75]):
    p += (oof_dict[key][pred_cols].to_numpy() ** 2) * w
print(metrics.f1_score(oof['target'],p.argmax(axis=1), average='micro'))


# test ensemble
p = np.zeros([len(test), 3])

for key, w in zip(['sakamiv1', 'sakamiv2', 'sakamiv3', 'shima_v0'], [0.2, 0.1, 0.1, 0.75]):
    p += (test_dict[key][pred_cols].to_numpy() ** 2) * w
# sub
test['target'] = p.argmax(axis=1)
test['category'] = test['target'].map({
    0: 'association',
    1: 'disagreement',
    2: 'unbiased',
})
# test[['id', 'category']].to_csv('../output/sub_ens.csv', index=False)
# Out:
# 0.8373096156048403
# 0.8420048097110356

# %%
import copy
oof_df = copy.deepcopy(oof_dict['sakamiv1'])[['id', 'target']]
for key in ['sakamiv1', 'sakamiv2', 'sakamiv3', 'sakamiv5', 'shima_v0']:
    xcols = [c for c in oof_dict[key].columns if c.startswith('f_')]
    oof_df = oof_df.merge(oof_dict[key][['id']+xcols])
tr = oof_df.copy()
test_df = copy.deepcopy(test_dict['sakamiv1'])[['id', 'target']]
for key in ['sakamiv1', 'sakamiv2', 'sakamiv3', 'sakamiv5', 'shima_v0']:
    xcols = [c for c in test_dict[key].columns if c.startswith('f_')]
    test_df = test_df.merge(test_dict[key][['id']+xcols])
tr = tr.merge(df[['id', 'sim1', 'sim2', 'sim3']])
test_df = test_df.merge(test_org[['id', 'sim1', 'sim2', 'sim3']])

# %%
lgb_params = {
        'learning_rate':0.01,
        "objective": "multiclass",
        'num_class': 3,
#         "metric": "rmse",
        'boosting_type': "gbdt", #trial.suggest_categorical("boosting_type", ["dart", "gbdt"]),
        'verbosity': -1,
        'n_jobs': -1,
        'seed': 19930820,
        "lambda_l1": 0,
        "lambda_l2": 0,
        "num_leaves": 8,
        "feature_fraction": 0.8,
        "bagging_fraction": 0.9,
        "bagging_freq": 1,
        'max_depth': -1,
        'max_bin':512,
    }
X_cols = [c for c in tr.columns if c not in ['id', 'target']]# + ['sim1', 'sim2', 'sim3']
target_col = 'target'
kf = model_selection.KFold(n_splits=4)
oof = np.zeros([len(tr), 3])
pred_stack_test = np.zeros([len(test), 3])
for tr_idx, va_idx in kf.split(tr):
    trn = tr.iloc[tr_idx]
    val = tr.iloc[va_idx]
    tr_D = lgb.Dataset(trn[X_cols], trn[target_col])
    va_D = lgb.Dataset(val[X_cols], val[target_col])
    model = lgb.train(lgb_params, tr_D, valid_sets=[va_D], num_boost_round=2000, early_stopping_rounds=100, verbose_eval=10)
    oof[va_idx, :] = model.predict(val[X_cols])
    pred_stack_test += model.predict(test_df[X_cols])
p = oof.argmax(axis=1)
metrics.f1_score(tr['target'], p, average='micro')
# Out:
# Training until validation scores don't improve for 100 rounds
# [10]	valid_0's multi_logloss: 0.983082
# [20]	valid_0's multi_logloss: 0.890491
# [30]	valid_0's multi_logloss: 0.815052
# [40]	valid_0's multi_logloss: 0.753015
# [50]	valid_0's multi_logloss: 0.700233
# [60]	valid_0's multi_logloss: 0.655572
# [70]	valid_0's multi_logloss: 0.618376
# [80]	valid_0's multi_logloss: 0.586163
# [90]	valid_0's multi_logloss: 0.558662
# [100]	valid_0's multi_logloss: 0.535445
# [110]	valid_0's multi_logloss: 0.515763
# [120]	valid_0's multi_logloss: 0.499002
# [130]	valid_0's multi_logloss: 0.484459
# [140]	valid_0's multi_logloss: 0.472172
# [150]	valid_0's multi_logloss: 0.461635
# [160]	valid_0's multi_logloss: 0.452585
# [480]	valid_0's multi_logloss: 0.421021
# [490]	valid_0's multi_logloss: 0.420951
# [500]	valid_0's multi_logloss: 0.420895
# [510]	valid_0's multi_logloss: 0.420837
# [520]	valid_0's multi_logloss: 0.42076
# [530]	valid_0's multi_logloss: 0.420686
# [540]	valid_0's multi_logloss: 0.420634
# [550]	valid_0's multi_logloss: 0.420603
# [560]	valid_0's multi_logloss: 0.420554
# [570]	valid_0's multi_logloss: 0.420529
# [580]	valid_0's multi_logloss: 0.420477
# [590]	valid_0's multi_logloss: 0.420471
# [600]	valid_0's multi_logloss: 0.420442
# [610]	valid_0's multi_logloss: 0.420433
# [620]	valid_0's multi_logloss: 0.420434
# [630]	valid_0's multi_logloss: 0.420419
# [640]	valid_0's multi_logloss: 0.420393
# [650]	valid_0's multi_logloss: 0.420394
# [660]	valid_0's multi_logloss: 0.420385
# [670]	valid_0's multi_logloss: 0.420353
# [680]	valid_0's multi_logloss: 0.420366
# [690]	valid_0's multi_logloss: 0.420361
# [700]	valid_0's multi_logloss: 0.420351
# [710]	valid_0's multi_logloss: 0.42035
# [720]	valid_0's multi_logloss: 0.420364
# [730]	valid_0's multi_logloss: 0.420358
# [740]	valid_0's multi_logloss: 0.42035
# [750]	valid_0's multi_logloss: 0.420356
# [760]	valid_0's multi_logloss: 0.420324
# [770]	valid_0's multi_logloss: 0.420302
# [780]	valid_0's multi_logloss: 0.420322
# [790]	valid_0's multi_logloss: 0.420308
# [800]	valid_0's multi_logloss: 0.420314
# [810]	valid_0's multi_logloss: 0.420287
# [820]	valid_0's multi_logloss: 0.420288
# [830]	valid_0's multi_logloss: 0.420267
# [840]	valid_0's multi_logloss: 0.420279
# [850]	valid_0's multi_logloss: 0.420306
# [860]	valid_0's multi_logloss: 0.420307
# [870]	valid_0's multi_logloss: 0.420313
# [880]	valid_0's multi_logloss: 0.420324
# [890]	valid_0's multi_logloss: 0.420358
# [900]	valid_0's multi_logloss: 0.420359
# [910]	valid_0's multi_logloss: 0.420356
# [920]	valid_0's multi_logloss: 0.420377
# [930]	valid_0's multi_logloss: 0.420374
# Early stopping, best iteration is:
# [830]	valid_0's multi_logloss: 0.420267
# 0.8447913883269077

# %%
lgb_params = {
        'learning_rate':0.01,
        "objective": "multiclass",
        'num_class': 3,
#         "metric": "rmse",
        'boosting_type': "gbdt", #trial.suggest_categorical("boosting_type", ["dart", "gbdt"]),
        'verbosity': -1,
        'n_jobs': -1,
        'seed': 19930820,
        "lambda_l1": 0,
        "lambda_l2": 0,
        "num_leaves": 8,
        "feature_fraction": 0.8,
        "bagging_fraction": 0.9,
        "bagging_freq": 1,
        'max_depth': -1,
        'max_bin':512,
    }
X_cols = [c for c in tr.columns if c not in ['id', 'target'] + ['sim1', 'sim2', 'sim3']]
target_col = 'target'
kf = model_selection.KFold(n_splits=4)
oof = np.zeros([len(tr), 3])
pred_stack_test = np.zeros([len(test), 3])
for tr_idx, va_idx in kf.split(tr):
    trn = tr.iloc[tr_idx]
    val = tr.iloc[va_idx]
    tr_D = lgb.Dataset(trn[X_cols], trn[target_col])
    va_D = lgb.Dataset(val[X_cols], val[target_col])
    model = lgb.train(lgb_params, tr_D, valid_sets=[va_D], num_boost_round=2000, early_stopping_rounds=100, verbose_eval=10)
    oof[va_idx, :] = model.predict(val[X_cols])
    pred_stack_test += model.predict(test_df[X_cols])
p = oof.argmax(axis=1)
metrics.f1_score(tr['target'], p, average='micro')
# Out:
# Training until validation scores don't improve for 100 rounds
# [10]	valid_0
# [320]	valid_0's multi_logloss: 0.425916
# [330]	valid_0's multi_logloss: 0.425293
# [340]	valid_0's multi_logloss: 0.42473
# [350]	valid_0's multi_logloss: 0.424236
# [360]	valid_0's multi_logloss: 0.423847
# [370]	valid_0's multi_logloss: 0.423466
# [380]	valid_0's multi_logloss: 0.42316
# [390]	valid_0's multi_logloss: 0.422873
# [400]	valid_0's multi_logloss: 0.42264
# [410]	valid_0's multi_logloss: 0.422416
# [420]	valid_0's multi_logloss: 0.422223
# [430]	valid_0's multi_logloss: 0.422063
# [440]	valid_0's multi_logloss: 0.42191
# [450]	valid_0's multi_logloss: 0.421791
# [460]	valid_0's multi_logloss: 0.42167
# [470]	valid_0's multi_logloss: 0.421587
# [480]	valid_0's multi_logloss: 0.421486
# [490]	valid_0's multi_logloss: 0.421408
# [500]	valid_0's multi_logloss: 0.42134
# [510]	valid_0's multi_logloss: 0.421258
# [520]	valid_0's multi_logloss: 0.421197
# [530]	valid_0's multi_logloss: 0.421155
# [540]	valid_0's multi_logloss: 0.421074
# [550]	valid_0's multi_logloss: 0.421043
# [560]	valid_0's multi_logloss: 0.420999
# [570]	valid_0's multi_logloss: 0.420985
# [580]	valid_0's multi_logloss: 0.420949
# [590]	valid_0's multi_logloss: 0.420939
# [600]	valid_0's multi_logloss: 0.420914
# [610]	valid_0's multi_logloss: 0.420916
# [620]	valid_0's multi_logloss: 0.420909
# [630]	valid_0's multi_logloss: 0.420905
# [640]	valid_0's multi_logloss: 0.420876
# [650]	valid_0's multi_logloss: 0.420873
# [660]	valid_0's multi_logloss: 0.420854
# [670]	valid_0's multi_logloss: 0.420848
# [680]	valid_0's multi_logloss: 0.420842
# [690]	valid_0's multi_logloss: 0.420861
# [700]	valid_0's multi_logloss: 0.420873
# [710]	valid_0's multi_logloss: 0.420876
# [720]	valid_0's multi_logloss: 0.420859
# [730]	valid_0's multi_logloss: 0.42086
# [740]	valid_0's multi_logloss: 0.420831
# [750]	valid_0's multi_logloss: 0.420812
# [760]	valid_0's multi_logloss: 0.420786
# [770]	valid_0's multi_logloss: 0.420777
# [780]	valid_0's multi_logloss: 0.420798
# [790]	valid_0's multi_logloss: 0.420791
# [800]	valid_0's multi_logloss: 0.42081
# [810]	valid_0's multi_logloss: 0.4208
# [820]	valid_0's multi_logloss: 0.420764
# [830]	valid_0's multi_logloss: 0.42076
# [840]	valid_0's multi_logloss: 0.420775
# [850]	valid_0's multi_logloss: 0.420786
# [860]	valid_0's multi_logloss: 0.420782
# [870]	valid_0's multi_logloss: 0.420786
# [880]	valid_0's multi_logloss: 0.420789
# [890]	valid_0's multi_logloss: 0.420786
# [900]	valid_0's multi_logloss: 0.420814
# [910]	valid_0's multi_logloss: 0.420816
# [920]	valid_0's multi_logloss: 0.420822
# Early stopping, best iteration is:
# [827]	valid_0's multi_logloss: 0.42075
# 0.844409665228843

# %%
sub = test_df[['id']].copy()
sub['target'] = pred_stack_test.argmax(axis=1)
sub['category'] = sub['target'].map({
    0: 'association',
    1: 'disagreement',
    2: 'unbiased',
})
sub[['id', 'category']].to_csv('../output/sub.csv', index=False)
